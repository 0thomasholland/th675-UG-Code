# %%
import csv
import matplotlib.pyplot as plt
import numpy as np
import math as math

# %%
a87Rb86Sr = np.array([])
a87Sr86Sr = np.array([])

with open('1A_Practical_49_Sourie_Sr.csv', 'r') as source:
    csv_reader = csv.reader(source)
    for line in csv_reader:
        print(line)
        if line[1] == '87Rb.86Sr':
            continue
        a87Rb86Sr = np.append(a87Rb86Sr, float(line[1]))
        a87Sr86Sr = np.append(a87Sr86Sr, float(line[2]))


# remove the value from each

a87Rb86Sr = a87Rb86Sr[1:]
a87Sr86Sr = a87Sr86Sr[1:]

print(a87Rb86Sr)
print(a87Sr86Sr)
# Out:
# ['\ufeffSample No.', '87Rb.86Sr', '87Sr.86Sr']
# ['1', '0.336', '0.71395']
# ['2', '0.133', '0.70665']
# ['3', '0.234', '0.71038']
# ['4', '0.352', '0.7144']
# ['5', '0.074', '0.70458']
# ['6', '0.297', '0.71221']
# ['7', '0.149', '0.70757']
# ['8', '0.488', '0.71901']
# ['9', '0.133', '0.70683']
# ['10', '0.266', '0.71149']
# ['11', '0.114', '0.70594']
# ['12', '0.429', '0.71717']
# [0.133 0.234 0.352 0.074 0.297 0.149 0.488 0.133 0.266 0.114 0.429]
# [0.70665 0.71038 0.7144  0.70458 0.71221 0.70757 0.71901 0.70683 0.71149
#  0.70594 0.71717]

# %%
# plot a graph of 87.Rb.86Sr against 87.Sr.86.Sr

plt.scatter(a87Rb86Sr, a87Sr86Sr)
# add trendline, extending the line to the y intercept
m_test, b_test = np.polyfit(a87Rb86Sr, a87Sr86Sr, 1)
plt.plot(a87Rb86Sr, m*a87Rb86Sr + b)
plt.xlabel('87Rb.86Sr')
plt.ylabel('87Sr.86Sr')
plt.show()

print('The slope of the line is', m)
print('The y intercept of the line is', b)
# Out:
# The slope of the line is 0.034836434224566906
# The y intercept of the line is 0.7021137779140569

# %%
def calc(gradient, lmbda):
    time = math.log(m+1) / (lmbda)
    return time

calc(m_test, 1.42*(10**-11))
# Out:
# 2411505610.0646996

# %%
data = csv.reader(open('U-pb_revised_data_compilation.csv', 'r', encoding = "ISO-8859-1"))
for line in data:
    if line[0] == 'Terrane':
        continue
    terrane.append(line[0])
    continent = line[1] 
    lat = float(line[2])
    long = float(line[3])
    Location1 = line[4]
    Location2 = line[5]
    LithoStrat1 = line[6]
    LithoStrat2 = line[7]
    MIV = line[8]
    Age = float(line[9])
    Error = float(line[10])
    Technique = line[11]


print(terrane)
# plot histogram of number of site vs age for when continent is either Laurentia or Laurentia Hebridean

# create a list of ages for when continent is Laurentia or Laurentia Hebridean

plot_ages = []
# Out:
# North Armorican
